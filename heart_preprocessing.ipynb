# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Loading and Preprocessing

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
df['target'].value_counts().plot.pie(autopct='%1.1f%%').title("Heart Disease Distribution")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 2
#       1 plt.figure(figsize=(10,5))
# ----> 2 df['target'].value_counts().plot.pie(autopct='%1.1f%%').title("Heart Disease Distribution")
#
# TypeError: 'Text' object is not callable

# %%
#two layer histogram for the Age and Osteoporosis
plt.figure(figsize=(10,5))
df[df['target']==1]['age'].plot.hist(bins=30, alpha=0.5, color='blue', label='target = 1')
df[df['target']==0]['age'].plot.hist(bins=30, alpha=0.5, color='red', label='target = 0')

#legends and title
plt.legend()
plt.xlabel('Age')
plt.title('Heart by Age')
# Out:
# Text(0.5, 1.0, 'Heart by Age')

# %%
sns.countplot(x='sex', data=df, hue = 'target').set_title("Heart Disease vs Sex")
# Out:
# Text(0.5, 1.0, 'Heart Disease vs Sex')

# %%
df.hist(bins=20, figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
corr = df.corr()
corr['target']
# Out:
# age        -0.229324
# sex        -0.279501
# cp          0.434854
# trestbps   -0.138772
# chol       -0.099966
# fbs        -0.041164
# restecg     0.134468
# thalach     0.422895
# exang      -0.438029
# oldpeak    -0.438441
# slope       0.345512
# ca         -0.382085
# thal       -0.337838
# target      1.000000
# Name: target, dtype: float64

# %%
target = corr['target'].sort_values()
target
# Out:
# oldpeak    -0.438441
# exang      -0.438029
# ca         -0.382085
# thal       -0.337838
# sex        -0.279501
# age        -0.229324
# trestbps   -0.138772
# chol       -0.099966
# fbs        -0.041164
# restecg     0.134468
# slope       0.345512
# thalach     0.422895
# cp          0.434854
# target      1.000000
# Name: target, dtype: float64

# %%
columns = df.columns.tolist()
columns
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
imp_columns=[]
for cols in columns:
    if target[cols] > 0.1 or target[cols] < -0.1:
        imp_columns.append(cols)

# %%
imp_columns
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
df_imp = pd.DataFrame()
for cols in imp_columns:
    df_imp[cols] = df[cols]
df_imp.head()
# Out:
#    age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  thal  \
# 0   52    1   0       125        1      168      0      1.0      2   2     3
# 1   53    1   0       140        0      155      1      3.1      0   0     3
# 2   70    1   0       145        1      125      1      2.6      0   0     3
# 3   61    1   0       148        1      161      0      0.0      2   1     3
# 4   62    0   0       138        1      106      0      1.9      1   3     2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
from sklearn.preprocessing import StandardScaler
cols = ['age', 'trestbps', 'thalach', 'oldpeak','chol']
ss = StandardScaler()
df[cols]=ss.fit_transform(df[cols])

# %%
df.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0 -0.268437    1   0 -0.377636 -0.659332    0        1  0.821321      0
# 1 -0.158157    1   0  0.479107 -0.833861    1        0  0.255968      1
# 2  1.716595    1   0  0.764688 -1.396233    0        1 -1.048692      1
# 3  0.724079    1   0  0.936037 -0.833861    0        1  0.516900      0
# 4  0.834359    0   0  0.364875  0.930822    1        1 -1.874977      0
#
#     oldpeak  slope  ca  thal  target
# 0 -0.060888      2   2     3       0
# 1  1.727137      0   0     3       0
# 2  1.301417      0   0     3       0
# 3 -0.912329      2   1     3       0
# 4  0.705408      1   3     2       0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
y = df['target']
X = df.drop(['target'], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
svc = []
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for k in range(len(kernels)):
    svc_classifier = SVC(kernel=kernels[k])
    svc_classifier.fit(X_train, y_train)
    svc.append(svc_classifier.score(X_test, y_test))

# %%
from matplotlib.cm import rainbow
colors = rainbow(np.linspace(0, 1, len(kernels)))
plt.bar(kernels, svc, color = colors)
for i in range(len(kernels)):
    plt.text(i, svc[i], svc[i])
plt.xlabel('Kernels')
plt.ylabel('Scores')
plt.title('Support Vector Classifier scores for different kernels')
# Out:
# Text(0.5, 1.0, 'Support Vector Classifier scores for different kernels')

# %%
for ker, score in zip(kernels, svc):
    print("The score for Support Vector Classifier is {:.2f}% with {} kernel.".format(score * 100, ker))
# Out:
# The score for Support Vector Classifier is 86.73% with linear kernel.
# The score for Support Vector Classifier is 91.15% with poly kernel.
# The score for Support Vector Classifier is 91.74% with rbf kernel.
# The score for Support Vector Classifier is 78.76% with sigmoid kernel.

# %% [markdown]
# ## Decision Tree Classifier

# %%
dt_scores = []
for i in range(1, len(X.columns) + 1):
    dt_classifier = DecisionTreeClassifier(max_features = i, random_state = 0)
    dt_classifier.fit(X_train, y_train)
    dt_scores.append(dt_classifier.score(X_test, y_test))

# %%
plt.figure(figsize=(15,15))
plt.plot([i for i in range(1, len(X.columns) + 1)], dt_scores, color = 'green')
for i in range(1, len(X.columns) + 1):
    plt.text(i, dt_scores[i-1], f'({i}, {dt_scores[i-1]:.2f})', ha='center', va='bottom')
plt.xticks([i for i in range(1, len(X.columns) + 1)])
plt.xlabel('Max features')
plt.ylabel('Scores')
plt.title('Decision Tree Classifier scores for different number of maximum features')
# Out:
# Text(0.5, 1.0, 'Decision Tree Classifier scores for different number of maximum features')

# %% [markdown]
# ## Random Forest Classifier

# %%
rf_scores = []
estimators = [10, 100, 200, 500, 1000]
for i in estimators:
    rf_classifier = RandomForestClassifier(n_estimators = i, random_state = 0)
    rf_classifier.fit(X_train, y_train)
    rf_scores.append(rf_classifier.score(X_test, y_test))

# %%
colors = rainbow(np.linspace(0, 1, len(estimators)))
plt.bar([i for i in range(len(estimators))], rf_scores, color = colors, width = 0.8)
for i in range(len(estimators)):
    plt.text(i, rf_scores[i], rf_scores[i])
plt.xticks(ticks = [i for i in range(len(estimators))], labels = [str(estimator) for estimator in estimators])
plt.xlabel('Number of estimators')
plt.ylabel('Scores')
plt.title('Random Forest Classifier scores for different number of estimators')
# Out:
# Text(0.5, 1.0, 'Random Forest Classifier scores for different number of estimators')
